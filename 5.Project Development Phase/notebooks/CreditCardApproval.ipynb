# %% [markdown]
# # Credit Card Approval - EDA and Modeling
# This notebook contains EDA, preprocessing, model training and evaluation steps.

# %%
import pandas as pd
df = pd.read_csv('../dataset/credit_card.csv')
df.head()
